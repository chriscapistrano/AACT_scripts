# %%
import pandas as pd

# %%
sheets_test = pd.read_excel('2029.xlsx')

# %%
sheets_test.head()
# Out:
#   Epoch Analysis Unnamed: 1     Unnamed: 2     Unnamed: 3   Unnamed: 4  \
# 0            NaN        NaN            NaN            NaN          NaN
# 1          Epoch       Time  Value (CH 14)  Delta (CH 14)  P-P (CH 14)
# 2              1        4.5     0.00152588              0    0.0050354
# 3              2       20.5     0.00167847    0.000762939     0.015564
# 4              3       36.5     0.00183105    0.000152588    0.0050354
#
#      Unnamed: 5     Unnamed: 6     Unnamed: 7   Unnamed: 8    Unnamed: 9
# 0           NaN            NaN            NaN          NaN           NaN
# 1  Mean (CH 14)  Value (CH 15)  Delta (CH 15)  P-P (CH 15)  Mean (CH 15)
# 2    0.00135846    -0.00167847    0.000305176   0.00549316   -0.00150893
# 3    0.00132342    -0.00320435   -0.000762939   0.00946045   -0.00148431
# 4    0.00132068    -0.00335693              0   0.00488281   -0.00150729

# %%
#read each sheet/tab within the excel document
#sheets = pd.read_excel('2014.xlsx', sheet_name=['block1', 'block2', 'block3', 'block4', 'block5', 
 #                                               'block6', 'block7', 'block8'])

sheets = pd.read_excel('2029.xlsx', sheet_name=['Sheet1', 'Sheet2', 'Sheet3', 'Sheet4', 'Sheet5', 
                                                'Sheet6', 'Sheet7', 'Sheet8'])

# %%
sheets
# Out:
# OrderedDict([('Sheet1',
#                  Epoch Analysis Unnamed: 1     Unnamed: 2     Unnamed: 3   Unnamed: 4  \
#               0             NaN        NaN            NaN            NaN          NaN
#               1           Epoch       Time  Value (CH 14)  Delta (CH 14)  P-P (CH 14)
#               2               1        4.5     0.00152588              0    0.0050354
#               3               2       20.5     0.00167847    0.000762939     0.015564
#               4               3       36.5     0.00183105    0.000152588    0.0050354
#               5               4       52.5    0.000762939   -0.000152588   0.00473022
#               6               5       68.5     0.00137329    0.000610352    0.0123596
#               7               6       84.5    0.000762939   -0.000152588   0.00473022
#               8               7      100.5      0.0012207    0.000457764   0.00396729
#               9               8      116.5      0.0012207    0.000305176   0.00701904
# ...

# %%
#concatinate/consolidate sheets 1-8 (aka blocks 1-8) into in 1 sheet 
df = pd.concat(sheets[frame] for frame in sheets.keys())

# %%
df.head()
# Out:
#   Epoch Analysis Unnamed: 1     Unnamed: 2     Unnamed: 3   Unnamed: 4  \
# 0            NaN        NaN            NaN            NaN          NaN
# 1          Epoch       Time  Value (CH 14)  Delta (CH 14)  P-P (CH 14)
# 2              1        4.5     0.00152588              0    0.0050354
# 3              2       20.5     0.00167847    0.000762939     0.015564
# 4              3       36.5     0.00183105    0.000152588    0.0050354
#
#      Unnamed: 5     Unnamed: 6     Unnamed: 7   Unnamed: 8    Unnamed: 9
# 0           NaN            NaN            NaN          NaN           NaN
# 1  Mean (CH 14)  Value (CH 15)  Delta (CH 15)  P-P (CH 15)  Mean (CH 15)
# 2    0.00135846    -0.00167847    0.000305176   0.00549316   -0.00150893
# 3    0.00132342    -0.00320435   -0.000762939   0.00946045   -0.00148431
# 4    0.00132068    -0.00335693              0   0.00488281   -0.00150729

# %%
#save as CSV to concat_df folder
df.to_csv('concat_df/2029.csv')

# %%
############################################
#part(y) 2!!! :)  
#clean the newly created sheet in the concat_df folder
#if column "Epoch Analysis" = NaN or Epoch, delete it
###########################################

# %%
df_read = pd.read_csv('concat_df/2029.csv')

# %%
df_read.columns
# Out:
# Index(['Unnamed: 0', 'Epoch Analysis', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
#delete index rows based on index 
df_read = df_read.drop(df_read.index[[0,1,26,27,52,53,78,79,104,105,130,131,156,157,182,183,]])

# %%
df_read.head()
# Out:
#    Unnamed: 0 Epoch Analysis Unnamed: 1         Unnamed: 2  \
# 2           2              1        4.5   0.00152587890625
# 3           3              2       20.5  0.001678466796875
# 4           4              3       36.5    0.0018310546875
# 5           5              4       52.5  0.000762939453125
# 6           6              5       68.5  0.001373291015625
#
#            Unnamed: 3         Unnamed: 4             Unnamed: 5  \
# 2                   0  0.005035400390625  0.0013584623067991845
# 3   0.000762939453125   0.01556396484375  0.0013234169660050544
# 4   0.000152587890625  0.005035400390625   0.001320680091771608
# 5  -0.000152587890625  0.004730224609375  0.0013308551607858494
# 6     0.0006103515625  0.012359619140625  0.0013328863601298356
#
#            Unnamed: 6          Unnamed: 7         Unnamed: 8  \
# 2  -0.001678466796875    0.00030517578125    0.0054931640625
# 3  -0.003204345703125  -0.000762939453125   0.00946044921875
# ...

# %%
df_read.to_csv('concat_df/2029.csv')
